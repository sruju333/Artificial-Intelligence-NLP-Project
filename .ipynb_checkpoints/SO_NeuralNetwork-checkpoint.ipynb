# %%
import os
import pandas as pd

# Convert the dataset from .csv to a Pandas DataFrame - so_df (Stack Overflow Dataframe)
so_df = pd.read_csv(os.path.join("/Users/srujana/Desktop/Artificial Intelligence/AI-FinalProject", "train.csv"), on_bad_lines='skip',engine="python", nrows=1000000)
# so_df = pd.read_csv('train.csv', on_bad_lines='skip',engine="python", nrows=1000000)

# %%
so_df
# Out:
#          PostId     PostCreationDate  OwnerUserId    OwnerCreationDate  \
# 0             4  07/31/2008 21:42:52            8  07/31/2008 21:33:24
# 1             6  07/31/2008 22:08:08            9  07/31/2008 21:35:26
# 2             8  07/31/2008 23:33:19            9  07/31/2008 21:35:26
# 3             9  07/31/2008 23:40:59            1  07/31/2008 14:22:31
# 4       9610539  03/07/2012 23:07:09      1021610  10/31/2011 08:26:49
# ...         ...                  ...          ...                  ...
# 999995  4359234  12/05/2010 14:26:44        48943  12/24/2008 17:45:49
# 999996  4359236  12/05/2010 14:27:11       109525  05/19/2009 18:11:05
# 999997  4359238  12/05/2010 14:28:09       387054  07/08/2010 18:55:49
# 999998  4359239  12/05/2010 14:28:16       277422  02/19/2010 23:36:08
# 999999  4359246  12/05/2010 14:30:21         3514  08/28/2008 21:53:55
#
#         ReputationAtPostCreation  OwnerUndeletedAnswerCountAtPostTime  \
# 0                              1                                    0
# 1                              1                                    0
# 2                             16                                    1
# 3                              1                                    1
# 4                             29                                    0
# ...                          ...                                  ...
# 999995                       526                                   30
# 999996                       204                                    3
# 999997                         1                                    0
# 999998                        48                                    0
# 999999                       143                                    3
#
#                                                     Title  \
# 0                                      Decimal vs Double?
# 1       Percentage width child in absolutely positione...
# 2                         Tools for porting J# code to C#
# 3                 How do I calculate someone's age in c#?
# 4          retrieve data from NSUserDefaults to TableView
# ...                                                   ...
# 999995  How to implement System.Security.Cryptography.DES
# 999996  Having a hard time getting started with Vim-R-...
# 999997  How do I get multiple values from checkboxes i...
# 999998                             XML support in Eclipse
# 999999  Good book on learning how to create icons in P...
#
#                                              BodyMarkdown            Tag1  \
# 0       I'm new to C#, and I want to use a trackbar fo...              c#
# 1       I've got an absolutely positioned div containi...            html
# 2       Are there any conversion tools for porting Vis...              j#
# 3       Given a DateTime representing their birthday, ...              c#
# 4       I save values of two labels through NSUserDefa...          iphone
# ...                                                   ...             ...
# 999995  I have the following static encryption class w...              c#
# 999996  I am trying to install the R-project (for stat...               r
# 999997  I want to get values of a multiple select chec...          python
# 999998  In android SDK, when I editing an android layo...         android
# 999999  I am a developer by trade and I don't pretend ...  user-interface
#
#                 Tag2               Tag3            Tag4        Tag5  \
# 0                NaN                NaN             NaN         NaN
# 1                css                NaN             NaN         NaN
# 2                NaN                NaN             NaN         NaN
# 3                NaN                NaN             NaN         NaN
# 4        objective-c               ios5             NaN         NaN
# ...              ...                ...             ...         ...
# 999995  cryptography  extension-methods      encryption         NaN
# 999996           vim         vim-plugin             NaN         NaN
# 999997        django      django-models        checkbox  checkboxes
# 999998           xml            eclipse             NaN         NaN
# 999999         icons          photoshop  graphic-design         NaN
#
#        PostClosedDate OpenStatus
# 0                 NaN       open
# 1                 NaN       open
# 2                 NaN       open
# 3                 NaN       open
# 4                 NaN       open
# ...               ...        ...
# 999995            NaN       open
# 999996            NaN       open
# 999997            NaN       open
# 999998            NaN       open
# 999999            NaN       open
#
# [1000000 rows x 15 columns]

# %%
so_df.shape
# Out:
# (1000000, 15)

# %%
so_df.tail(5)
# Out:
#          PostId     PostCreationDate  OwnerUserId    OwnerCreationDate  \
# 999995  4359234  12/05/2010 14:26:44        48943  12/24/2008 17:45:49
# 999996  4359236  12/05/2010 14:27:11       109525  05/19/2009 18:11:05
# 999997  4359238  12/05/2010 14:28:09       387054  07/08/2010 18:55:49
# 999998  4359239  12/05/2010 14:28:16       277422  02/19/2010 23:36:08
# 999999  4359246  12/05/2010 14:30:21         3514  08/28/2008 21:53:55
#
#         ReputationAtPostCreation  OwnerUndeletedAnswerCountAtPostTime  \
# 999995                       526                                   30
# 999996                       204                                    3
# 999997                         1                                    0
# 999998                        48                                    0
# 999999                       143                                    3
#
#                                                     Title  \
# 999995  How to implement System.Security.Cryptography.DES
# 999996  Having a hard time getting started with Vim-R-...
# 999997  How do I get multiple values from checkboxes i...
# 999998                             XML support in Eclipse
# 999999  Good book on learning how to create icons in P...
#
#                                              BodyMarkdown            Tag1  \
# 999995  I have the following static encryption class w...              c#
# 999996  I am trying to install the R-project (for stat...               r
# 999997  I want to get values of a multiple select chec...          python
# 999998  In android SDK, when I editing an android layo...         android
# 999999  I am a developer by trade and I don't pretend ...  user-interface
#
#                 Tag2               Tag3            Tag4        Tag5  \
# 999995  cryptography  extension-methods      encryption         NaN
# 999996           vim         vim-plugin             NaN         NaN
# 999997        django      django-models        checkbox  checkboxes
# 999998           xml            eclipse             NaN         NaN
# 999999         icons          photoshop  graphic-design         NaN
#
#        PostClosedDate OpenStatus
# 999995            NaN       open
# 999996            NaN       open
# 999997            NaN       open
# 999998            NaN       open
# 999999            NaN       open

# %%
import matplotlib.pyplot as plt

# Assuming df is your DataFrame containing the 'OpenStatus' column
so_df['OpenStatus'].value_counts().plot(kind='bar', title='Class Distribution')
plt.xlabel('OpenStatus')
plt.ylabel('Count')
plt.show()

# %%
# Checking the number of samples from each class

class_distribution = so_df['OpenStatus'].value_counts()
print(class_distribution)
# Out:
# OpenStatus
# open                   988350
# not constructive         5143
# off topic                3069
# not a real question      2920
# too localized             518
# Name: count, dtype: int64

# %%
# Check for NaN or missing values in the dataframe
import seaborn as sns

# Create a boolean DataFrame indicating NaN values
nan_indicator_df = so_df.isnull()

# Plot heatmap for NaN values
plt.figure(figsize=(10, 6))
sns.heatmap(nan_indicator_df, cbar=False, cmap='YlGnBu')
plt.title('Heatmap of NaN Values in DataFrame')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# Splitting the dataset into train, validation and test (80%, 10% and 10% respectively)
so_train_df, remaining = train_test_split(so_df, random_state=42, train_size=0.8, stratify=so_df.OpenStatus.values)
so_valid_df, so_test_df = train_test_split(remaining, random_state=42, train_size=0.50, stratify=remaining.OpenStatus.values)

# Display the shapes of the downsampled training and validation datasets
so_train_df.shape, so_valid_df.shape, so_test_df.shape
# Out:
# ((800000, 15), (100000, 15), (100000, 15))
